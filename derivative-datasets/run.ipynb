# %%
import os

# glob through xml files in "/home/jcuenod/Programming/symphony-stuff/symphony-backend-atlas-internal/data/Clear-Bible/macula-greek/SBLGNT/lowfat"
import glob

for qualified_filename in glob.glob("/home/jcuenod/Programming/symphony-stuff/symphony-backend-atlas-internal/data/Clear-Bible/macula-greek/SBLGNT/lowfat/*.xml"):
    filename = os.path.basename(qualified_filename)
    print("--------------------------------------------------------------------")
    print("--------------------------------------------------------------------")
    print("--------------------------------------------------------------------")
    print(filename)
    # set environ INPUT_FILE_NAME = filename
    os.environ["INPUT_FILE_NAME"] = filename
    # %run -n ./backgrounded-phrases.ipynb
# Out:
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# 07-1corinthians.xml
# Number of words: 6812
# Παῦλος
# κλητὸς
# ἀπόστολος
# Χριστοῦ
# Ἰησοῦ
# Number of main clauses: 927
# Εὐχαριστῶ
# ἐπλουτίσθητε
# ἐβεβαιώθη
# ὑστερεῖσθαι
# βεβαιώσει
# Number of adjunct participle candidates: 25
# 1CO 2:1    ἦλθον                ἐλθὼν
# 1CO 4:12   εὐλογοῦμεν           λοιδορούμενοι
# 1CO 4:12   ἀνεχόμεθα            διωκόμενοι
# 1CO 4:13   παρακαλοῦμεν         δυσφημούμενοι
# 1CO 4:14   γράφω                ἐντρέπων
# 1CO 4:18   ἐφυσιώθησάν          ἐρχομένου
# 1CO 5:3    κέκρικα              ἀπὼν/παρὼν
# 1CO 5:5    παραδοῦναι           συναχθέντων
# 1CO 6:15   ποιήσω               ἄρας
# 1CO 7:18   ἐκλήθη               περιτετμημένος
# 1CO 8:7    μολύνεται            οὖσα
# 1CO 8:10   οἰκοδομηθήσεται      ὄντος
# ...
